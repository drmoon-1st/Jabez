# %%
#!/usr/bin/env python3
"""
clean_CSVMP4.py

"""
import sys
from pathlib import Path

def clean_folder(csv_dir: Path, video_dir: Path):
    """
    csv_dir, video_dir 폴더의 CSV/MP4 파일을 1:1 매칭하여
    대응되지 않는 파일을 삭제합니다.
    """
    print(f"-- Cleaning: {csv_dir.parent.name} --")
    if not csv_dir.is_dir():
        print(f"Error: {csv_dir} 폴더가 없습니다.")
        return
    if not video_dir.is_dir():
        print(f"Error: {video_dir} 폴더가 없습니다.")
        return

    ext_csv = ".csv"
    ext_video = ".mp4"

    csv_files = list(csv_dir.glob(f"*{ext_csv}"))
    video_files = list(video_dir.glob(f"*{ext_video}"))

    csv_stems = {f.stem for f in csv_files}
    video_stems = {f.stem for f in video_files}

    unmatched_csv = csv_stems - video_stems
    unmatched_video = video_stems - csv_stems

    for stem in unmatched_csv:
        path = csv_dir / f"{stem}{ext_csv}"
        try:
            path.unlink()
            print(f"Removed unmatched CSV: {path}")
        except Exception as e:
            print(f"Failed to remove {path}: {e}")

    for stem in unmatched_video:
        path = video_dir / f"{stem}{ext_video}"
        try:
            path.unlink()
            print(f"Removed unmatched video: {path}")
        except Exception as e:
            print(f"Failed to remove {path}: {e}")

    print(f"Completed: {csv_dir.parent.name}\n")


def main():
    # test 폴더로 청소, train 원하면 train으로 변경
    base_dir = Path(r"D:\golfDataset\dataset\train")
    # 상위 폴더 리스트 (balanced_true, false)
    parents = ["balanced_true", "false"]

    for parent in parents:
        csv_dir = base_dir / parent / "crop_keypoint"
        video_dir = base_dir / parent / "crop_video"
        clean_folder(csv_dir, video_dir)

    print("All cleaning tasks finished.")

if __name__ == "__main__":
    main()
# Out:
# -- Cleaning: balanced_true --
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201126_General_047_DOS_A_M30_MM_030_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201201_General_063_DOS_A_M50_MS_022_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201202_General_067_DOS_A_M50_SM_001_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201203_General_070_DOS_A_M20_MM_072_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201126_General_047_DOS_A_M30_MM_058_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201126_General_047_DOS_A_M30_MM_046_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201202_General_066_DOC_A_M40_MM_033_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201125_General_042_DOS_A_M20_MS_012_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201203_General_071_DOS_A_M40_MM_048_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201202_General_066_DOC_A_M40_MM_090_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201130_General_057_DOS_A_M50_MM_030_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201201_General_061_DOS_A_M40_MM_003_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201125_General_043_DOS_A_M20_MS_041_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201201_General_063_DOS_A_M50_MS_048_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201127_General_051_DOS_A_M40_MM_034_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201201_General_064_DOS_A_M50_MM_015_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201126_General_046_DOS_A_M30_MM_012_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201202_General_066_DOC_A_M40_MM_011_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201124_General_040_DOS_A_M40_MM_038_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201127_General_055_DOC_A_M40_MM_072_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201127_General_051_DOS_A_M40_MM_039_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201203_General_070_DOS_A_M20_MM_030_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201202_General_067_DOS_A_M50_SM_019_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201130_General_059_DOS_A_M50_MM_004_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201127_General_050_DOS_A_M40_MM_075_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201127_General_055_DOC_A_M40_MM_056_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201125_General_043_DOS_A_M20_MS_014_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201125_General_043_DOS_A_M20_MS_012_crop.mp4
# Removed unmatched video: D:\golfDataset\dataset\train\balanced_true\crop_video\20201203_General