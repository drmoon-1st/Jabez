# %%
import cv2
import mediapipe as mp
import pandas as pd
import os
from pathlib import Path
from collections import defaultdict
import numpy as np

# 관절 이름 매핑
LANDMARK_NAMES = [
    "nose", "left_eye_inner", "left_eye", "left_eye_outer", "right_eye_inner", "right_eye",
    "right_eye_outer", "left_ear", "right_ear", "mouth_left", "mouth_right", "left_shoulder",
    "right_shoulder", "left_elbow", "right_elbow", "left_wrist", "right_wrist", "left_pinky",
    "right_pinky", "left_index", "right_index", "left_thumb", "right_thumb", "left_hip",
    "right_hip", "left_knee", "right_knee", "left_ankle", "right_ankle", "left_heel",
    "right_heel", "left_foot_index", "right_foot_index"
]

mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

def imread_unicode(path):
    try:
        stream = np.fromfile(str(path), dtype=np.uint8)
        img = cv2.imdecode(stream, cv2.IMREAD_COLOR)
        return img
    except Exception as e:
        print(f"[예외 발생] {path} → {e}")
        return None
    
def extract_pose(image_path):
    image = imread_unicode(image_path)
    if not image_path.exists():
        print(f"[파일 없음] {image_path}")
    if image is None:
        print(f"[로드 실패] {image_path}")
        return None

    with mp_pose.Pose(static_image_mode=True) as pose:
        results = pose.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        if not results.pose_landmarks:
            # 관절 미검출 시 모든 값을 NaN으로 처리
            return {name: {"x": np.nan, "y": np.nan, "z": np.nan, "visibility": np.nan} for name in LANDMARK_NAMES}

        landmarks = results.pose_landmarks.landmark
        data = {
            name: {
                "x": landmarks[idx].x if landmarks[idx].visibility > 0 else np.nan,
                "y": landmarks[idx].y if landmarks[idx].visibility > 0 else np.nan,
                "z": landmarks[idx].z if landmarks[idx].visibility > 0 else np.nan,
                "visibility": landmarks[idx].visibility if landmarks[idx].visibility > 0 else np.nan
            }
            if idx < len(landmarks) else {
                "x": np.nan, "y": np.nan, "z": np.nan, "visibility": np.nan
            }
            for idx, name in enumerate(LANDMARK_NAMES)
        }
        return data

def process_directory(input_dir, output_dir):
    input_dir = Path(input_dir)
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    # 시퀀스별로 파일 그룹화
    sequences = defaultdict(list)
    for img_path in input_dir.glob("*.jpg"):
        parts = img_path.stem.split("_")
        if len(parts) < 6:
            print(f"[경고] 잘못된 파일명: {img_path.name}")
            continue
        sequence_name = "_".join(parts[:-1])
        sequences[sequence_name].append(img_path)


    # 각 시퀀스 처리
    for sequence, files in sequences.items():
        sequence_data = []
        files = sorted(files)  # 시퀀스 정렬
        for img_path in files:
            pose_data = extract_pose(img_path)
            if pose_data is None:
                continue
            pose_data_flat = {}
            for joint_name, values in pose_data.items():
                for key in ["x", "y", "z", "visibility"]:
                    pose_data_flat[f"{joint_name}_{key}"] = values[key]
            pose_data_flat["filename"] = img_path.name
            sequence_data.append(pose_data_flat)

        if sequence_data:
            df = pd.DataFrame(sequence_data)
            save_path = output_dir / f"{sequence}.csv"
            df.to_csv(save_path, index=False)
            print(f"[저장 완료] {save_path}")
        else:
            print(f"[스킵] 유효한 프레임 없음: {sequence}")

# ✅ 처리 대상 경로 설정
base_dir = Path(r"D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf")

process_directory(
    input_dir=base_dir / "true" / "cropped",
    output_dir=base_dir / "true" / "skel_csv"
)

process_directory(
    input_dir=base_dir / "false" / "cropped",
    output_dir=base_dir / "false" / "skel_csv"
)
# Out:
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_001.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_002.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_003.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_007.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_008.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_009.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_010.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_011.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_012.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_014.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_015.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_022.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_024.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_029.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_030.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_032.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201116_General_001_DOS_A_M40_MM_034.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201117_General_007_DOC_A_M40_MM_017.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201117_General_007_DOC_A_M40_MM_018.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201117_General_007_DOC_A_M40_MM_029.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201117_General_007_DOC_A_M40_MM_030.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201117_General_007_DOC_A_M40_MM_032.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201117_General_007_DOC_A_M40_MM_033.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201117_General_007_DOC_A_M40_MM_035.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201117_General_007_DOC_A_M40_MM_039.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201117_General_007_DOC_A_M40_MM_040.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201117_General_007_DOC_A_M40_MM_043.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201117_General_007_DOC_A_M40_MM_046.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201117_General_007_DOC_A_M40_MM_047.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201117_General_007_DOC_A_M40_MM
csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_DOR_A_M40_MM_046.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_DOR_A_M40_MM_047.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_DOR_A_M40_MM_048.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_DOR_A_M40_MM_049.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_DOR_A_M40_MM_050.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_NOC_A_M40_MM_051.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_NOC_A_M40_MM_053.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_NOC_A_M40_MM_054.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_NOC_A_M40_MM_055.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_NOC_A_M40_MM_057.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_NOC_A_M40_MM_059.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_NOC_A_M40_MM_060.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_NOC_A_M40_MM_062.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_NOC_A_M40_MM_063.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_018_NOC_A_M40_MM_064.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_002.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_003.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_004.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_006.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_007.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_008.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_009.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_010.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_011.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_012.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_013.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_015.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_016.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_017.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_018.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_019.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_020.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_021.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_022.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_023.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_024.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_025.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_026.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_028.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_029.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_047.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_051.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_053.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_054.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOC_A_M30_MM_055.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOR_A_M30_MM_030.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOR_A_M30_MM_032.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOR_A_M30_MM_034.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOR_A_M30_MM_035.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOR_A_M30_MM_037.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOR_A_M30_MM_045.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_DOR_A_M30_MM_046.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_058.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_061.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_062.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_063.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_064.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_065.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_066.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_067.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_068.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_069.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_070.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_071.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_073.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201118_General_019_NOC_A_M30_MM_074.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_001.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_004.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_006.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_011.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_015.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_016.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_017.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_018.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_019.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_020.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_021.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_022.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_023.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_024.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_025.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_026.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201120_General_021_DOC_A_M40_MM_027.csv
# ...
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\true\skel_csv\20201124_General_036_DOS_A_M50_MM_065.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_043.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_044.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_046.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_047.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_051.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_052.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_053.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_054.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_056.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_058.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_061.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_062.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_065.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_067.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_068.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201116_General_001_DOS_A_M40_MM_069.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_003.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_004.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_005.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_006.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_007.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_009.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_010.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_011.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_012.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_013.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_014.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_015.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_016.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_020.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_021.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_022.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_023.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_025.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_026.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_027.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_028.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_029.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_030.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_031.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_032.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_033.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_034.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_036.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_038.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_039.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_040.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_049.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_059.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_060.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_061.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_005_DOC_A_M40_MM_062.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_002.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_003.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_004.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_008.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_009.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_011.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_012.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_013.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_016.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_017.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_018.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_019.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_020.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_021.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_025.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_026.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_027.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_031.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_032.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_033.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_035.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_036.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_040.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_041.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_043.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_044.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_045.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_047.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_048.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_049.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_053.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_054.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_057.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_058.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_059.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_060.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_064.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_065.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_066.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_067.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_068.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_069.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201117_General_006_DOC_A_M40_BS_070.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_029_DOS_A_M40_MM_062.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_001.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_002.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_003.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_004.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_005.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_006.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_007.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_008.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_009.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_010.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_011.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_012.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_014.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_015.csv
# [저장 완료] D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf\false\skel_csv\20201123_General_030_DOS_A_M40_MM_016.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 107
#     100 base_dir = Path(r"D:\golfDataset\스포츠 사람 동작 영상(골프)\Training\Public\male\tf")
#     102 process_directory(
#     103     input_dir=base_dir / "true" / "cropped",
#     104     output_dir=base_dir / "true" / "skel_csv"
#     105 )
# --> 107 process_directory(
#     108     input_dir=base_dir / "false" / "cropped",
#     109     output_dir=base_dir / "false" / "skel_csv"
#     110 )
#
# Cell In[1], line 81, in process_directory(input_dir, output_dir)
#      79 files = sorted(files)  # 시퀀스 정렬
#      80 for img_path in files:
# ---> 81     pose_data = extract_pose(img_path)
#      82     if pose_data is None:
#      83         continue
#
# Cell In[1], line 40, in extract_pose(image_path)
#      37     return None
#      39 with mp_pose.Pose(static_image_mode=True) as pose:
# ---> 40     results = pose.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#      41     if not results.pose_landmarks:
#      42         # 관절 미검출 시 모든 값을 NaN으로 처리
#      43         return {name: {"x": np.nan, "y": np.nan, "z": np.nan, "visibility": np.nan} for name in LANDMARK_NAMES}
#
# File c:\Users\qqppq\anaconda3\envs\golfCNN\lib\site-packages\mediapipe\python\solutions\pose.py:185, in Pose.process(self, image)
#     164 def process(self, image: np.ndarray) -> NamedTuple:
#     165   """Processes an RGB image and returns the pose landmarks on the most prominent person detected.
#     166
#     167   Args:
#    (...)
#     182          "enable_segmentation" is set to true.
#     183   """
# --> 185   results = super().process(input_data={'image': image})
#     186   if results.pose_landmarks:  # pytype: disable=attribute-error
#     187     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File c:\Users\qqppq\anaconda3\envs\golfCNN\lib\site-packages\mediapipe\python\solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:
