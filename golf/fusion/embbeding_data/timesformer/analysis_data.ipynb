# %%
import numpy as np

X = np.load("train_embeddings.npy")
y = np.load("train_labels.npy")
print(X.shape)  # -> (샘플 개수, 임베딩 차원)
print(y.shape)  # -> (샘플 개수,)
# Out:
# (393, 2)
# (393,)

# %%
print(X)
# Out:
# [[ 4.53559071e-01 -2.63610065e-01]
#  [ 3.53537649e-01 -3.36468279e-01]
#  [ 3.16143006e-01  1.41106725e-01]
#  [-1.34616077e-01 -1.28742903e-01]
#  [-2.79045314e-01 -2.72066683e-01]
#  [-2.66802579e-01 -6.06223047e-01]
#  [ 2.88246453e-01 -1.26298487e-01]
#  [ 2.78371394e-01 -3.75080734e-01]
#  [ 5.04699469e-01 -1.96217850e-01]
#  [ 2.95468479e-01  3.10055703e-01]
#  [ 8.27325344e-01 -2.22202405e-01]
#  [ 1.15305953e-01  1.17445759e-01]
#  [ 2.17299610e-01  7.11091161e-02]
#  [-5.57696521e-02 -2.91950196e-01]
#  [-1.95663527e-01 -4.54048634e-01]
#  [ 3.88199359e-01 -8.84761661e-02]
#  [ 2.94694692e-01  3.08219552e-01]
#  [-4.61628400e-02 -8.94178674e-02]
#  [ 3.67296666e-01 -5.80085933e-01]
#  [-1.63515117e-02 -3.61010522e-01]
#  [-4.74302098e-02 -1.89216480e-01]
#  [ 4.10129607e-01 -1.47915483e-01]
#  [-2.24487975e-01 -3.35321158e-01]
#  [ 1.42761156e-01  1.71065018e-01]
#  [ 8.30803871e-01  3.73316318e-01]
#  [ 1.69424340e-01  1.11267082e-01]
#  [-2.16110777e-02  2.82528877e-01]
# ...
